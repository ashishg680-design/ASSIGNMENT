# %% [markdown]
# <a href="https://colab.research.google.com/github/nakulverma12/assignment-9/blob/main/ASSIGNMENT_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #***Supervised Learning : Regression Models and Performance Metrics***

# %% [markdown]
# ###***1. What is Simple Linear Regression (SLR)? Explain its purpose .***

# %% [markdown]
# **Simple Linear Regression (SLR)** is a statistical method used to model the relationship between **one independent variable (X)** and **one dependent variable (Y)** by fitting a straight line to the observed data.

# %% [markdown]
# ####***Definition -***
#
# Simple Linear Regression assumes a linear relationship of the form :

# %% [markdown]
#                           Y = β₀ + β₁X + ε

# %% [markdown]
# Where :
#
# *  **Y** = dependent (response) variable
#
# * **X** = independent (predictor) variable
#
# * **β₀ (intercept)** = value of Y when X = 0
#
# * **β₁ (slope)** = change in Y for a one-unit change in X
#
#
# * **ε** = error term (random noise)

# %% [markdown]
# ###***Purpose of Simple Linear Regression***
#
# ####**(I) Understand Relationships -**
#
# It helps determine **how strongly and in what direction X** affects Y
#
# * Positive slope → Y increases as X increases
#
# *  Negative slope → Y decreases as X increases

# %% [markdown]
# ####**(II) Prediction -**
#
# Once the model is fitted, it can be used to **predict the value of Y** for a given value of X
#
# * Example : Predicting salary based on years of experience

# %% [markdown]
# ####**(III) Quantify Impact -**
#
# The slope (β₁) quantifies the **magnitude of change** in Y due to X
#
# * Example : “For every additional year of experience, salary increases by ₹50,000”

# %% [markdown]
# ####**(IV) Trend Analysis -**
#
# Identifies and summarizes trends in data using a simple, interpretable model

# %% [markdown]
# ###***2. What are the key assumptions of Simple Linear Regression ?***

# %% [markdown]
# Simple Linear Regression (SLR) relies on a set of assumptions to ensure that the model is valid and that statistical inferences (like confidence intervals and hypothesis tests) are reliable. The key assumptions are :

# %% [markdown]
# ####**(I) Linearity -**
#
# * The relationship between the independent variable X and the dependent variable Y is linear.
#
# * Mathematically :
#
#              Y =  β0​ + β1​X + ε
#
# * **Check :** Scatter plot of X vs Y.

# %% [markdown]
# ####**(II) Independence of Errors -**
#
# *  The residuals (errors) are **independent** of each other.
#
# * Violations often occur in time-series data (autocorrelation).
#
# *  **Check :** Durbin–Watson test, residuals vs. time plot.

# %% [markdown]
# ####**(III) Homoscedasticity (Constant Variance) -**
#
# * The variance of the errors is **constant** across all values of **X**.
#
# * If variance changes with **X**, it is called **heteroscedasticity**.
#
# * **Check :** Residuals vs. fitted values plot.

# %% [markdown]
# ####**(IV) Normality of Errors -**
#
# * The residuals are **normally distributed** (mainly required for hypothesis testing and confidence intervals) .
#
# * **Check :** Histogram of residuals, Q–Q plot.

# %% [markdown]
# ####**(V) Zero Mean of Errors -**
#
# * The expected value of the error term is zero :
#
#                       E(ε)=0
#
# *  Ensures the regression line is unbiased.

# %% [markdown]
# ####**(VI) No Perfect Multicollinearity (Trivial in SLR) -**
#
# * In SLR, there is only one predictor, so this assumption is automatically satisfied.
#
# * Mentioned mainly for consistency with multiple regression.

# %% [markdown]
# ###***3. Write the mathematical equation for a simple linear regression model and explain each term.***

# %% [markdown]
# ####**Mathematical Equation of Simple Linear Regression**
#
# The simple linear regression (SLR) model is written as :
#
#                         Y = β0 ​+ β1​X + ε

# %% [markdown]
# ####**(I) Y-Dependent (Responce) Variable -**
#
# * This is the variable we want to **predict or explain** .
#
# * Example : house price, exam score, sales revenue .

# %% [markdown]
# ####**(II) X – Independent (Predictor) Variable -**
#
# * This is the variable used to **predict Y** .
#
# * Example: house area, hours studied, advertising spend .

# %% [markdown]
# ####**(III) β0 – Intercept -**
#
# *  The expected value of **Y** when **X = 0**.
#
# * It represents where the regression line **cuts the Y-axis** .

# %% [markdown]
# ####**(IV) β1 – Slope (Regression Coefficient) -**
#
# * Represents the **change in Y** for a **one-unit increase in X**.
#
# * If 𝛽1 > 0 : positive relationship
#
# * If 𝛽1 < 0 : negative relationship

# %% [markdown]
# ####**(V) ε – Error Term (Residual) -**
#
# * Captures the **random variation** in **Y** not explained by **X** .
#
# * Accounts for measurement errors, omitted variables, and noise .

# %% [markdown]
# ###***4. Provide a real-world example where simple linear regression can be applied .***

# %% [markdown]
# ####**Scenario : Predicting House Price Based on Area**
#
# A real estate company wants to estimate the **price of a house** using its **area (in square feet)**. From past data, they observe that as the area increases, the house price generally increases in a roughly linear way .

# %% [markdown]
# ####**Variables -**
#
# *  **Independent variable (X)** : House area (in square feet)
#
# * **Dependent variable (Y)** : House price (in lakhs or dollars)

# %% [markdown]
# ####**Simple Linear Regression Model**
#
#                         House Price = β0​ + β1 ​× (Area) + ε

# %% [markdown]
# ####**Interpretation -**
#
# * **β0 (Intercept)** : Estimated base price when the area is zero (theoretically ; may not have practical meaning) .
#
# * **β1 (Slope)** : Increase in house price for each additional square foot of area .
#
# * **ε (Error term)** : Captures factors not included in the model, such as location, age of the house, or market conditions.

# %% [markdown]
# ####**Practical Use -**
#
# If the fitted model is :
#
#                      House Price = 10 + 0.05 × (Area)

# %% [markdown]
# * A 1 sq. ft increase in area increases the house price by **0.05 units** .
#
# * A house with 1,000 sq. ft area would have a predicted price of :
#
#                     10 + 0.05 × 1000 = 60

# %% [markdown]
# ####**Why Simple Linear Regression Fits Here**
#
# * Only **one main predictor** (area) is considered.
#
# * The relationship between area and price is **approximately linear** .
#
# * Easy to interpret and useful for **quick predictions** .

# %% [markdown]
# ###***5. What is the method of least squares in linear regression?***

# %% [markdown]
# **The Method of Least Squares** is a technique used in linear regression to estimate the model parameters (coefficients) so that the regression line best fits the observed data.

# %% [markdown]
# ####**Core Idea -**
#
# It finds the line (or hyperplane) that **minimizes the sum of the squared differences** between the observed values and the values predicted by the regression model .
#
# These differences are called **residuals** .

# %% [markdown]
# ####**In Simple Linear Regression -**
#
# The model is :
#
#                            y = β0 ​+ β1​x + ε

# %% [markdown]
# Where :
#
# * **y** = dependent variable
#
# * **x** = independent variable
#
# * **β0** = intercept
#
# * **β1** = slope
#
# *  **ε** = error term

# %% [markdown]
# ###***6. What is Logistic Regression? How does it differ from Linear Regression ?***

# %% [markdown]
# **Logistic Regression** is a **supervised learning algorithm** used for **classification problems** , especially when the **dependent variable is categorical** (most commonly binary) .
#
# Instead of predicting a continuous value, logistic regression predicts the **probability** that an observation belongs to a particular class .
#
# For binary classification :

# %% [markdown]
#                        P(Y = 1 ∣ X) = 1/e^(-z)

# %% [markdown]
# Where z = β0 ​+ β1​x1 ​+⋯+ βnxn

# %% [markdown]
# This function is called the **sigmoid (logistic) function** , and it maps any real value into the range **(0, 1)** .

# %% [markdown]
# | Aspect             | Linear Regression           | Logistic Regression                                      |
# | ------------------ | --------------------------- | -------------------------------------------------------- |
# | Problem type       | Regression                  | Classification                                           |
# | Output             | Continuous value            | Probability (0 to 1)                                     |
# | Dependent variable | Continuous                  | Categorical (usually binary)                             |
# | Model equation     | ( y = \beta_0 + \beta_1 x ) | ( \log\left(\frac{p}{1-p}\right) = \beta_0 + \beta_1 x ) |
# | Function used      | Identity function           | Sigmoid (logistic) function                              |
# | Estimation method  | Least Squares               | Maximum Likelihood Estimation                            |
# | Error distribution | Normal                      | Binomial                                                 |
# | Output range       | ( (-\infty, +\infty) )      | ( (0, 1) )                                               |

# %% [markdown]
# ###***7. Name and briefly describe three common evaluation metrics for regression models .***

# %% [markdown]
# ####**(I) Mean Absolute Error (MAE) -**

# %% [markdown]
# Measures the average absolute difference between actual and predicted values. It is easy to interpret and treats all errors equally.

# %% [markdown]
#                           MAE = 1/n ∑n ​∣ yi​−y^​i ​∣

# %% [markdown]
# ####**(II) Mean Squared Error (MSE) -**

# %% [markdown]
# Calculates the average of the squared differences between actual and predicted values. It penalizes larger errors more heavily due to squaring.

# %% [markdown]
#                            MSE = 1/n ​∑ ( yi ​− y^​i​) ^2

# %% [markdown]
# ####**(III) oot Mean Squared Error (RMSE) -**

# %% [markdown]
# The square root of MSE. It has the same units as the target variable, making it easier to interpret while still emphasizing larger errors.

# %% [markdown]
#                      RMSE = (MSE) ^ (1/2)
# ​

# %% [markdown]
# ###***8. What is the purpose of the R-squared metric in regression analysis ?***

# %% [markdown]
# **R-squared** (𝑅^2) measures how well a regression model explains the variability of the dependent (target) variable.

# %% [markdown]
# ####**Purpose of R-squared**
#
# *  It indicates the **proportion of variance in the dependent variable that is explained by the independent variables** in the model.
#
# * It helps assess the **goodness of fit** of a regression model.

# %% [markdown]
# ####**Interpretation**
#
# * R^2 = 1 : The model explains **100%** of the variance (perfect fit) .
#
# * R^2 = 0 : The model explains **none** of the variance .
#
# * Example: R^2 = 0.80 means **80% of the variation** in the target variable is explained by the model.

# %% [markdown]
# ####**Key Points**
#
# * Higher R^2 generally indicates a better fit, but it **does not guarantee** the model is appropriate.
#
# * **R^2 always increases** (or stays the same) when more predictors are added, even if they are not useful.
#
# * For multiple predictors, **Adjusted R-squared** is preferred as it penalizes unnecessary variables.
#
#
# *   List item

# %% [markdown]
# ###***9. Write Python code to fit a simple linear regression model using scikit-learn and print the slope and intercept.***
# ###***(Include your Python code and output in the code box below.)***

# %%
# Import required libraries
import numpy as np
from sklearn.linear_model import LinearRegression

# Sample data
X = np.array([10, 20, 30, 40, 50]).reshape(-1, 1)
y = np.array([15, 25, 35, 45, 55])

# Create and train the model
model = LinearRegression()
model.fit(X, y)

# Print slope and intercept
print("Slope (Coefficient):", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Slope (Coefficient): 1.0
# Intercept: 5.0

# %% [markdown]
# This output means the fitted regression equation is :
#
#                         y = 1.0x + 5.0

# %% [markdown]
# ###***10. How do you interpret the coefficients in a simple linear regression model ?***

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Sample data
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)   # Independent variable
y = np.array([3, 5, 7, 9, 11])               # Dependent variable

# Fit the model
model = LinearRegression()
model.fit(X, y)

# Extract coefficients
slope = model.coef_[0]
intercept = model.intercept_

print("Slope (Coefficient):", slope)
print("Intercept:", intercept)

# Interpretation
print(f"\nInterpretation:")
print(f"For every 1-unit increase in X, Y increases by {slope}.")
print(f"When X = 0, the predicted value of Y is {intercept}.")
# Out:
# Slope (Coefficient): 2.0
# Intercept: 1.0
#
# Interpretation:
# For every 1-unit increase in X, Y increases by 2.0.
# When X = 0, the predicted value of Y is 1.0.
